# %%
---
layout: post
categories: [Final]
title: CSSE2 Individual Final
description: 
type: issues 
comments: true
permalink: /CSSE_FINAL
sticky_rank: 1
---

# %% [markdown]
# # Introduction
# When I first came to this class, I was very unsure of what I was doing. I'd considered dropping it many times (sorry Mr. Mortensen) but to be honest, I am glad I didn't. Without this class, there are so many skills and so many amazing people I would have never came to know. Throughout this class, I have learned many things; not only hard skills in coding, but soft skills, like presenting work and communicating with a team, thanks to the heavy group environment. This blog is an overview of all I have learned throughout CSSE2.

# %% [markdown]
# # Overview of Work
# Throughout this trimester, I have brought much to my team, dedicating much of my time and effort. This includes:
#
# **Enemies** - Created custom enemies that allow for an immersive-user experience; fully fledged with their own features. This includes:
# - *Randomly moving enemies* - Allows for a factor of suspense, keeping the player invested in the game and creating an objective for the player.
# - *Reactions for enemies* - Creates a more immersive experience for the player (also, it stops the game from feeling like a boring bunch of code).
# - *Enemy animations* - A simple and fun way to add interest to our game.
#
# **Platformer** - Created a simple platformer level that continues on from our original RPG level, creating diversity within our game.
#
# **Lessons** - Created easily understandable and simple lessons that allow for coders to learn from our code.
# - This also includes a soft skill of being able to present to many in a digestible way, also being open to any type of question and responding in a teachable manner.
#
# **Bonus: Sprite Sheets** - Creating custom sprite sheets, creating the "homemade" feel, as well as giving our game a greater sense of uniqueness.

# %% [markdown]
# # Certification of Articulation Success
# I have successfully integrated many different aspects of code into both my personal game and the team game, such as:
#
# ### Software Engineering Practices:
# *Planning changes, checklists, burndowns, coding with comments, building help documentation*
# While working with a team, it is important to maintain proper communication throughout the group. This is why creating plans, checklists, communicating changes, coding with comments, as well as help documentations and burndowns are so important. There are many instances of this communication in our code, like in our bee motion method:
#
# ```js
# // Bee random motion logic
# let beeBuzzAngle = 0;
# function updateBeeMotion() {
#   beeSpriteData.x += beeSpriteData.direction.x * beeSpriteData.speed;
#   // Bounce off canvas edges
#   if (beeSpriteData.x < 0) {
#     beeSpriteData.x = 0;
#     beeSpriteData.direction.x = 1;
#   }
#   if (beeSpriteData.x > canvas.width - beeSpriteData.width) {
#     beeSpriteData.x = canvas.width - beeSpriteData.width;
#     beeSpriteData.direction.x = -1;
#   }
#   // Occasionally change direction
#   if (Math.random() < 0.03) {
#     beeSpriteData.direction.x *= -1;
#   }
#   // Animate sprite (if you have multiple frames)
#   beeSpriteData.frameCounter++;
#   if (beeSpriteData.frameCounter >= beeSpriteData.ANIMATION_RATE) {
#     beeSpriteData.frameX = (beeSpriteData.frameX + 1) % 1; // Set to number of frames if animated
#     beeSpriteData.frameCounter = 0;
#   }
#   beeBuzzAngle += 0.1;
#   beeSpriteData.y = 100 + Math.sin(beeBuzzAngle) * 20; // 200 is base Y, 20 is amplitude
# }
# ```
# Or you can look at our chats in our shared groupchat on slack, which has most of the plans and ideas we've made (I'm half-joking).
#
# ### Software Development Lifecycle Practices:
# *Source control, forking, branching, building, testing and verification, pull requests, merging/integrating, deployment*
#
# When working with a group, it is crucial to keep track of changes made by each of group members. Being with a group has taugh me how to make use of the many features on both VS Code and GitHub that allow all of us to keep track of our group's progress when working on things. Forking, branching, building, testing and verification, merging/integrating, deployment; these are all ways of making sure independently that changes made to a piece of code works before integrating it into a larger piece of code, allowing for an organized manner of distributing tasks among many.
#
# ### Retrospective Engineering Practices:
# *Presentation, live reviews, demos, code reviews, revising plans*
#
# Being in this class has taught me much about being able to present code. This is much more a soft skill, yet is still very very important to my growth in this class, as presenting (not only code) is generally just a great skill to have, and is very important in many other fields of life. Things like lessons, live reviews, presenting at N@tM have all taught me how to be a great presenter that not only shows off code, but keeps the audience engaged.
#
# ### Data Types
# *Numbers, strings, booleans, arrays, JSON objects*
# There are many instances of these data types in my code. Data types are crucial for storing important information in code so it can be later referenced. An example of this:
#
# ```js
# // Rat Guide data
#     const sprite_src_guide = path + "/images/gamify/king.png"; // be sure to include the path
#     const sprite_greet_guide_intro = ""; //not needed for right now
#     const sprite_greet_guide_info = "";
#     const dialogueSystem = this.dialogueSystem;
#     const sprite_data_guide = {
#       id: 'Rat Guide',
#       greeting_intro: sprite_greet_guide_intro,
#       greeting_info: sprite_greet_guide_info,
#       src: sprite_src_guide,
#       SCALE_FACTOR: 10,  // adjust this based on your scaling needs
#       ANIMATION_RATE: 100,
#       pixels: { width: 1200, height: 1580 },
#       INIT_POSITION: { x: width * (7 / 8), y: height - (height / PLAYER_SCALE_FACTOR) },
#       orientation: { rows: 1, columns: 1 },
#       down: { row: 0, start: 0, columns: 1 },
#       hitbox: { widthPercentage: 0.1, heightPercentage: 0.2 },
#       reaction: function () {
#         dialogueSystem.showDialogue(`King: "Welcome to the Boiling Isles! Although charming, we need to find a way back home. Why not explore the town?" (Press 'E' to continue)`); // using custome dialogue system instead of alert
#         console.log("reacted with tomb guard ishfjhersfiqwe")
#       },
#       interact: () => {
#         if (gameEnv.gameControl) {
#           // goes back to the gamecontrol level classes array
#           gameEnv.gameControl.currentLevelIndex = 1;
#           gameEnv.gameControl.transitionToLevel();
#         }
#         console.log("going to town level")
#       }
#     };
# ```
# The sprite data that is defined in almost, if not every level of the Adventure Game is a great example on how we use data types to store information. There are instances of numbers, strings, JSON objects, yet not so much booleans or arrays, but you get the idea.
#
# ### Operations:
# *String operations, mathematical operations, boolean expressions*
# Though there are not many string operations in my code, an example of one is found in the sprite data of many of the NPCs:
# ```js
# const sprite_src_guide = path + "/images/gamify/king.png";
# ```
# Mathematical operations, there are many more instances of, but here is one that is also found in the sprite data:
# ```js
# INIT_POSITION: { x: width * (7 / 8), y: height - (height / PLAYER_SCALE_FACTOR) },
# ```
# And an example of a boolean expression that is not found in my code:
# ```js
# // Reverse direction if the guard reaches the max distance
#             if (this.INIT_POSITION.x > initialX + maxDistance || this.INIT_POSITION.x < initialX - maxDistance) {
#                 direction *= -1;
#
#                 // Flip the sprite horizontally based on direction
#                 const spriteElement = document.getElementById(this.id); // Ensure the sprite has an ID matching its `id` property
#                 if (spriteElement) {
#                     spriteElement.style.transform = direction === -1 ? 'scaleX(1)' : 'scaleX(-1)';
#                 }
#             }
# ```
#
# ### Control Structure:
# *Iteration, conditions, nested conditions*
# An example of an iteration:
# ```js
# quizData.questions.forEach(question => {
#         const correctAnswer = question.options[question.correctAnswer];
#         const shuffledOptions = question.options
#           .map(option => ({ option, sort: Math.random() }))
#           .sort((a, b) => a.sort - b.sort)
#           .map(({ option }) => option);
#         question.correctAnswer = shuffledOptions.indexOf(correctAnswer);
#         question.options = shuffledOptions;
#       });
# ```
# A condition:
# ```js
# if (callback) callback();
# ```
# And a nested condition:
# ```js
# if (this.INIT_POSITION.x > initialX + maxDistance || this.INIT_POSITION.x < initialX - maxDistance) {
#   direction *= -1;
#   if (spriteElement) {
#     spriteElement.style.transform = direction === -1 ? 'scaleX(1)' : 'scaleX(-1)';
#   }
# }
# ```
# (And yes, I did use this for my boolean expression as well)
#
# ### Input/Output
# *HTML5 input, validation, Key events, Document Object Model (DOM)*
# An example of HTML5 input/validation/key events:
# ```js
# keypress: { up: 87, left: 65, down: 83, right: 68 }
# // → mapped to keyboard keys W, A, S, D
# ```
# DOM Manipulation:
# ```js
# const spriteElement = document.getElementById(this.id); // Ensure the sprite has an ID matching its `id` property
#         if (spriteElement) {
#                     spriteElement.style.transform = direction === -1 ? 'scaleX(1)' : 'scaleX(-1)';
#         }
# ```
#
# ### Classes
# *Writing classes, creating methods, instantiating objects, using objects, calling methods, parameters, return values*
# An example of writing classes:
# well... all of the game levels are classes. Infact, all of the .js files are classes. Here is a very short one:
# ```js
# class Background {
#     constructor(data, gameEnv) {
#         this.image = new window.Image();
#         this.image.src = data.src;
#         this.gameEnv = gameEnv;
#     }
#     update() {
#         const ctx = this.gameEnv.ctx;
#         ctx.drawImage(this.image, 0, 0, this.gameEnv.width, this.gameEnv.height);
#     }
#     resize() {}
#     destroy() {}
# }
# export default Background;
# ```
# There many instances of methods in my code, for example, the `destroy()` method above.
#
# There are also many examples of instantiating objects, like:
# ```js
# let quiz = new Quiz();
# ```
# An example of using objects and calling methods:
# ```js
# dialogueSystem.showDialogue(...);
# gameInGame.start();
# ```
# Parameters and return values:
# ```js
# function customAlert(message, callback) { ... }
# // → takes parameters, may call `callback()` (a function)
# ```
#
# ### Coding Practices:
# *SRP, Object Literal, Object Instance, FSMs in Game, Inheritance*
# Single Responsibility Principle is a very important one when making classes--that each class or function is responsible for one thing. If you were to look at the different files in my adventureGame directory, you'd see that each file (class) has one single responsibility.
#
# An example of an object literal:
# ```js
# const sprite_data_guide = { ... };
# ```
# An example of an object instance (and yes, I have used this example before):
# ```js
# let quiz = new Quiz();
# ```
# An example of FSMs (Finite State Machines):
# ```js
# gameEnv.gameControl.currentLevelIndex = 1;
# gameEnv.gameControl.transitionToLevel();
# // → managing game states through a controller
# ```
# An example of inhertiance:
# ```js
# class Npc extends Character
# ```

# %% [markdown]
# # How I've Showcased Projects
# A lot of the time, I've showcased projects with the rest of my group, which is great because it distributes the pressure of presenting. I've had to learn to quickly come up with answers to questions I wasn't prepared for, which has trained me to become a fast thinker. It's also helped me to get to know my code well; people are here to learn what I've created, and yes the demo is interesting, but what's behind the demo is equally as important, and it is crucial I know every bit of my code in order to fully and properly present it to others. This includes not only knowing what's written, but knowing the function of each and every part of code (like the data types above!).

# %% [markdown]
# # Statistics
# ![Stats](./images/stats.png)
#
# # Grade Predictor Results
# ![Grade](./images/grade.png)
# ![Smartgrade](./images/smartgrade.png)
